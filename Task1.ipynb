# %% [markdown]
# <a href="https://colab.research.google.com/github/Pramana31/CodeAlpha_Python_Programming/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def hangman():
    words = ["python", "computer", "program", "network", "science"]

    word = random.choice(words)
    guessed_letters = []
    attempts = 6

    print("=" * 50)
    print("          HANGMAN GAME")
    print("=" * 50)
    print("Guess the word one letter at a time.")
    print("You have 6 incorrect attempts.\n")

    while attempts > 0:
        display_word = ""

        for letter in word:
            if letter in guessed_letters:
                display_word += letter + " "
            else:
                display_word += "_ "

        print("\nWord:", display_word)

        # Check win condition
        if "_" not in display_word:
            print("\nCongratulations! You guessed the word:", word)
            break

        guess = input("Enter a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter a single alphabet.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess in word:
            print("Correct Guess!")
        else:
            attempts -= 1
            print("Wrong Guess!")
            print("Remaining Attempts:", attempts)

    if attempts == 0:
        print("\nGame Over!")
        print("The word was:", word)

# Function Call
hangman()
# Out:
# ==================================================
#           HANGMAN GAME
# ==================================================
# Guess the word one letter at a time.
# You have 6 incorrect attempts.
#
#
# Word: _ _ _ _ _ _ _ _
# Enter a letter: s
# Wrong Guess!
# Remaining Attempts: 5
#
# Word: _ _ _ _ _ _ _ _
# Enter a letter: c
# Correct Guess!
#
# Word: c _ _ _ _ _ _ _
# Enter a letter: o
# Correct Guess!
#
# Word: c o _ _ _ _ _ _
# Enter a letter: m
# Correct Guess!
#
# Word: c o m _ _ _ _ _
# Enter a letter: p
# Correct Guess!
#
# Word: c o m p _ _ _ _
# Enter a letter: u
# Correct Guess!
#
# Word: c o m p u _ _ _
# Enter a letter: t
# Correct Guess!
#
# Word: c o m p u t _ _
# Enter a letter: e
# Correct Guess!
#
# Word: c o m p u t e _
# Enter a letter: r
# Correct Guess!
#
# Word: c o m p u t e r
#
# Congratulations! You guessed the word: computer
